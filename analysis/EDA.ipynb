# %%
import pandas as pd
import numpy as np

from analyzer.basic_data_inspection import DataInspector, DataTypesInspectionStrategy, SummaryStatisticsInspectionStrategy
from analyzer.missing_values_analysis import SimpleMissingValuesAnalysis
from analyzer.univariate_analysis import UnivariateAnalyzer, NumericalUnivariateAnalysis, CategoricalUnivariateAnalysis
from analyzer.bivariate_analysis import BivariateAnalyzer, NumericalVsNumericalAnalysis, CategoricalVsNumericalAnalysis
from analyzer.multivariate_analysis import SimpleMultivariateAnalysis

# Set display options for better readability
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv("../clean_data/cleaned_credit_data.csv")
df.head()
# Out:
#         ID  Gender Has a car Has a property  Children count    Income  \
# 0  5008804    Male       Yes            Yes               0  427500.0
# 1  5008805    Male       Yes            Yes               0  427500.0
# 2  5008806    Male       Yes            Yes               0  112500.0
# 3  5008808  Female        No            Yes               0  270000.0
# 4  5008809  Female        No            Yes               0  270000.0
#
#       Employment status                Education level        Marital status  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
#             Dwelling    Age  Employment length Has a mobile phone  \
# ...

# %% [markdown]
# # Explore the data

# %% [markdown]
# ## Basic Data Inspection

# %%
data_inspector = DataInspector(DataTypesInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Data Types and Non-null Counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36457 entries, 0 to 36456
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   36457 non-null  int64
#  1   Gender               36457 non-null  object
#  2   Has a car            36457 non-null  object
#  3   Has a property       36457 non-null  object
#  4   Children count       36457 non-null  int64
#  5   Income               36457 non-null  float64
#  6   Employment status    36457 non-null  object
#  7   Education level      36457 non-null  object
#  8   Marital status       36457 non-null  object
#  9   Dwelling             36457 non-null  object
#  10  Age                  36457 non-null  int64
#  11  Employment length    36457 non-null  int64
#  12  Has a mobile phone   36457 non-null  object
#  13  Has a work phone     36457 non-null  object
# ...

# %% [markdown]
# ## Summary Statistics Inspection

# %%
data_inspector.set_strategy(SummaryStatisticsInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Summary Statistics (Numerical Features):
#                  ID  Children count        Income           Age  \
# count  3.032200e+04    30322.000000  3.032200e+04  30322.000000
# mean   5.078951e+06        0.507222  1.943934e+05     40.556622
# std    4.186659e+04        0.781850  1.044873e+05      9.606048
# min    5.008804e+06        0.000000  2.700000e+04     20.500000
# 25%    5.042320e+06        0.000000  1.350000e+05     32.700000
# 50%    5.079020e+06        0.000000  1.800000e+05     39.900000
# 75%    5.115610e+06        1.000000  2.250000e+05     47.800000
# max    5.150487e+06       19.000000  1.575000e+06     67.400000
#
#        Employment length  Family member count   Account age  Is high risk
# count       30322.000000         30322.000000  30322.000000  30322.000000
# mean            7.247602             2.289460     26.223699      0.016589
# std             6.458601             0.942046     16.445764      0.127726
# ...

# %% [markdown]
# ## Missing Values Analysis

# %%
missing_values_analyzer = SimpleMissingValuesAnalysis()
missing_values_analyzer.analyze(df)
# Out:
# Missing Values Count by Column:
# Job title    11323
# dtype: int64
#
# Visualizing Missing Values...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Analyzing a Numerical Feature

# %% [markdown]
# ### Income

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Income')

# %% [markdown]
# ### Age

# %%
univariate_analyzer.execute_analysis(df, 'Age')

# %% [markdown]
# ### Employment length

# %%
univariate_analyzer.execute_analysis(df, 'Employment length')

# %% [markdown]
# ### Account age

# %%
univariate_analyzer.execute_analysis(df, 'Account age')

# %% [markdown]
# # Analyzing a Categorical Feature

# %% [markdown]
# ## Gender

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Gender')

# %% [markdown]
# ## Has a car

# %%
univariate_analyzer.execute_analysis(df, 'Has a car')

# %% [markdown]
# ## Has a property

# %%
univariate_analyzer.execute_analysis(df, 'Has a property')

# %% [markdown]
# ## Children count

# %%
univariate_analyzer.execute_analysis(df, 'Children count')

# %% [markdown]
# ## Employment status

# %%
univariate_analyzer.execute_analysis(df, 'Employment status')

# %% [markdown]
# ## Education level

# %%
univariate_analyzer.execute_analysis(df, 'Education level')

# %% [markdown]
# ## Marital status

# %%
univariate_analyzer.execute_analysis(df, 'Marital status')

# %% [markdown]
# ## Dwelling

# %%
univariate_analyzer.execute_analysis(df, 'Dwelling')

# %% [markdown]
# ## Has a mobile phone

# %%
univariate_analyzer.execute_analysis(df, 'Has a mobile phone')

# %% [markdown]
# ## Has a work phone

# %%
univariate_analyzer.execute_analysis(df, 'Has a work phone')

# %% [markdown]
# ## Has a phone

# %%
univariate_analyzer.execute_analysis(df, 'Has a work phone')

# %% [markdown]
# ## Has an email

# %%
univariate_analyzer.execute_analysis(df, 'Has an email')

# %% [markdown]
# ## Job title

# %%
univariate_analyzer.execute_analysis(df, 'Job title')

# %% [markdown]
# ## Family member count

# %%
univariate_analyzer.execute_analysis(df, 'Family member count')

# %% [markdown]
# ## Is high risk (Target Variable)

# %%
univariate_analyzer.execute_analysis(df, 'Is high risk')

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Numerical vs numerical features

# %% [markdown]
# ### Employment length vs age

# %%
bivariate_analyzer = BivariateAnalyzer(NumericalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Employment length', 'Age')

# %% [markdown]
# ### Employment length vs Income

# %%
bivariate_analyzer.execute_analysis(df, 'Income', 'Employment length')

# %% [markdown]
# ## Categorical vs Numerical Feature

# %% [markdown]
# ### Gender vs Income vs Age

# %%
bivariate_analyzer.set_strategy(CategoricalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Gender', 'Income')

# %%
bivariate_analyzer.execute_analysis(df, 'Gender', 'Age')

# %% [markdown]
# ### Employment status vs Income vs Age

# %%
bivariate_analyzer.execute_analysis(df, 'Employment status', 'Income')

# %%
bivariate_analyzer.execute_analysis(df, 'Employment status', 'Age')

# %% [markdown]
# ### Education level vs Income vs Age

# %%
bivariate_analyzer.execute_analysis(df, 'Education level', 'Income')

# %%
bivariate_analyzer.execute_analysis(df, 'Education level', 'Age')

# %%
bivariate_analyzer.execute_analysis(df, 'Is high risk', 'Age')

# %% [markdown]
# # Multivariate Analysis

# %%
multivariate_analyzer = SimpleMultivariateAnalysis()

selected_features = df[['Children count', 'Income', 'Age', 'Employment length',
 'Family member count', 'Account age', 'Is high risk']]

multivariate_analyzer.analyze(selected_features)
